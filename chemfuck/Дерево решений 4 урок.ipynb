# %%
import pandas as pd

# %%
df = pd.read_csv('winequalityN.csv')
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6463 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6463 non-null   object
#  1   fixed acidity         6463 non-null   float64
#  2   volatile acidity      6463 non-null   float64
#  3   citric acid           6463 non-null   float64
#  4   residual sugar        6463 non-null   float64
#  5   chlorides             6463 non-null   float64
#  6   free sulfur dioxide   6463 non-null   float64
#  7   total sulfur dioxide  6463 non-null   float64
#  8   density               6463 non-null   float64
#  9   pH                    6463 non-null   float64
#  10  sulphates             6463 non-null   float64
#  11  alcohol               6463 non-null   float64
#  12  quality               6463 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 706.9+ KB

# %%
df['color'] = 0
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality  color
# 0       0.45      8.8        6      0
# 1       0.49      9.5        6      0
# 2       0.44     10.1        6      0
# 3       0.40      9.9        6      0
# 4       0.40      9.9        6      0

# %%
for i in range(len(df)):
  if df.iloc[i,0] == 'red': df.iloc[i,-1] = 1
df.sample(5)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 144   white            8.1              0.20         0.40             2.0
# 3136  white            5.6              0.19         0.27             0.9
# 5685    red           10.0              0.56         0.24             2.2
# 2469  white            6.8              0.34         0.10             1.4
# 5577    red           10.8              0.26         0.45             3.3
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 144       0.037                 19.0                  87.0  0.99210  3.12
# 3136      0.040                 52.0                 103.0  0.99026  3.50
# 5685      0.079                 19.0                  58.0  0.99910  3.18
# 2469      0.049                 29.0                 118.0  0.99360  3.21
# 5577      0.060                 20.0                  49.0  0.99720  3.13
#
#       sulphates  alcohol  quality  color
# 144        0.54     11.2        6      0
# 3136       0.39     11.2        5      0
# 5685       0.56     10.1        6      1
# 2469       0.41      9.5        5      0
# 5577       0.54      9.6        5      1

# %%
df.drop('type', axis=1, inplace=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6      0
# 1      9.5        6      0
# 2     10.1        6      0
# 3      9.9        6      0
# 4      9.9        6      0

# %%
df.to_csv('winequality_clear.csv', index=False)

# %%
df.drop('quality', axis=1, inplace=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  color
# 0      8.8      0
# 1      9.5      0
# 2     10.1      0
# 3      9.9      0
# 4      9.9      0

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import metrics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6463 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6463 non-null   float64
#  1   volatile acidity      6463 non-null   float64
#  2   citric acid           6463 non-null   float64
#  3   residual sugar        6463 non-null   float64
#  4   chlorides             6463 non-null   float64
#  5   free sulfur dioxide   6463 non-null   float64
#  6   total sulfur dioxide  6463 non-null   float64
#  7   density               6463 non-null   float64
#  8   pH                    6463 non-null   float64
#  9   sulphates             6463 non-null   float64
#  10  alcohol               6463 non-null   float64
#  11  color                 6463 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 656.4 KB

# %%
x_train, x_test, y_train, y_test =  train_test_split(df.iloc[:,:-1], df.iloc[:,-1], 
   shuffle=True, random_state=1240, train_size=0.8)

# %%
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (5170, 11) (5170,) (1293, 11) (1293,)

# %%
clf = tree.DecisionTreeClassifier(max_depth=5, random_state=1240)
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=1240)

# %%
y_pred = clf.predict(x_test)

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9860788863109049

# %%
f_names = df.iloc[:,:-1].columns
c_names = ['Белое', 'Красное']
print(f_names)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,20))
a = tree.plot_tree(clf, feature_names=f_names, class_names=c_names,
                   filled=True, fontsize=14)
plt.show()

# %%
c_mat = metrics.confusion_matrix(y_test, y_pred)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(5,5))
sns.heatmap(c_mat, annot=True, fmt='d', cmap='magma')
plt.xlabel('Predicted')
plt.xticks(ticks=[0.5,1.5], labels=c_names)
plt.yticks(ticks=[0.5,1.5], labels=c_names)
plt.ylabel('True')
plt.show()

# %%
tree_rules = tree.export_text(clf, feature_names=list(f_names))
print(tree_rules)
# Out:
# |--- total sulfur dioxide <= 69.50
# |   |--- chlorides <= 0.05
# |   |   |--- sulphates <= 0.56
# |   |   |   |--- volatile acidity <= 0.66
# |   |   |   |   |--- class: 0
# |   |   |   |--- volatile acidity >  0.66
# |   |   |   |   |--- sulphates <= 0.42
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- sulphates >  0.42
# |   |   |   |   |   |--- class: 1
# |   |   |--- sulphates >  0.56
# |   |   |   |--- volatile acidity <= 0.33
# |   |   |   |   |--- total sulfur dioxide <= 23.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- total sulfur dioxide >  23.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- volatile acidity >  0.33
# |   |   |   |   |--- total sulfur dioxide <= 54.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- total sulfur dioxide >  54.50
# |   |   |   |   |   |--- class: 0
# |   |--- chlorides >  0.05
# |   |   |--- sulphates <= 0.38
# |   |   |   |--- citric acid <= 0.12
# |   |   |   |   |--- class: 1
# |   |   |   |--- citric acid >  0.12
# |   |   |   |   |--- class: 0
# |   |   |--- sulphates >  0.38
# |   |   |   |--- density <= 0.99
# |   |   |   |   |--- pH <= 3.20
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- pH >  3.20
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- density >  0.99
# |   |   |   |   |--- residual sugar <= 11.70
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- residual sugar >  11.70
# |   |   |   |   |   |--- class: 0
# |--- total sulfur dioxide >  69.50
# |   |--- chlorides <= 0.07
# |   |   |--- volatile acidity <= 0.83
# |   |   |   |--- sulphates <= 1.12
# |   |   |   |   |--- pH <= 3.83
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- pH >  3.83
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- sulphates >  1.12
# |   |   |   |   |--- class: 1
# |   |   |--- volatile acidity >  0.83
# |   |   |   |--- fixed acidity <= 6.20
# |   |   |   |   |--- class: 1
# |   |   |   |--- fixed acidity >  6.20
# |   |   |   |   |--- class: 0
# |   |--- chlorides >  0.07
# |   |   |--- volatile acidity <= 0.41
# |   |   |   |--- total sulfur dioxide <= 89.00
# |   |   |   |   |--- density <= 0.99
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- density >  0.99
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- total sulfur dioxide >  89.00
# |   |   |   |   |--- fixed acidity <= 7.75
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- fixed acidity >  7.75
# |   |   |   |   |   |--- class: 1
# |   |   |--- volatile acidity >  0.41
# |   |   |   |--- total sulfur dioxide <= 157.00
# |   |   |   |   |--- density <= 0.99
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- density >  0.99
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- total sulfur dioxide >  157.00
# |   |   |   |   |--- class: 0

# %% [markdown]
# Сохраняем решение дерева, а после открываем

# %%
import pickle

pickle.dump(clf, open('decision_tree.pickle', 'wb')) #формат для сохранения в файл

# %%
clf_loaded = pickle.load(open('decision_tree.pickle', 'rb')) #формат для хранения

# %%
tree_rules = tree.export_text(clf_loaded, feature_names=list(f_names))
print(tree_rules)
# Out:
# |--- total sulfur dioxide <= 69.50
# |   |--- chlorides <= 0.05
# |   |   |--- sulphates <= 0.56
# |   |   |   |--- volatile acidity <= 0.66
# |   |   |   |   |--- class: 0
# |   |   |   |--- volatile acidity >  0.66
# |   |   |   |   |--- sulphates <= 0.42
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- sulphates >  0.42
# |   |   |   |   |   |--- class: 1
# |   |   |--- sulphates >  0.56
# |   |   |   |--- volatile acidity <= 0.33
# |   |   |   |   |--- total sulfur dioxide <= 23.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- total sulfur dioxide >  23.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- volatile acidity >  0.33
# |   |   |   |   |--- total sulfur dioxide <= 54.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- total sulfur dioxide >  54.50
# |   |   |   |   |   |--- class: 0
# |   |--- chlorides >  0.05
# |   |   |--- sulphates <= 0.38
# |   |   |   |--- citric acid <= 0.12
# |   |   |   |   |--- class: 1
# |   |   |   |--- citric acid >  0.12
# |   |   |   |   |--- class: 0
# |   |   |--- sulphates >  0.38
# |   |   |   |--- density <= 0.99
# |   |   |   |   |--- pH <= 3.20
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- pH >  3.20
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- density >  0.99
# |   |   |   |   |--- residual sugar <= 11.70
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- residual sugar >  11.70
# |   |   |   |   |   |--- class: 0
# |--- total sulfur dioxide >  69.50
# |   |--- chlorides <= 0.07
# |   |   |--- volatile acidity <= 0.83
# |   |   |   |--- sulphates <= 1.12
# |   |   |   |   |--- pH <= 3.83
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- pH >  3.83
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- sulphates >  1.12
# |   |   |   |   |--- class: 1
# |   |   |--- volatile acidity >  0.83
# |   |   |   |--- fixed acidity <= 6.20
# |   |   |   |   |--- class: 1
# |   |   |   |--- fixed acidity >  6.20
# |   |   |   |   |--- class: 0
# |   |--- chlorides >  0.07
# |   |   |--- volatile acidity <= 0.41
# |   |   |   |--- total sulfur dioxide <= 89.00
# |   |   |   |   |--- density <= 0.99
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- density >  0.99
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- total sulfur dioxide >  89.00
# |   |   |   |   |--- fixed acidity <= 7.75
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- fixed acidity >  7.75
# |   |   |   |   |   |--- class: 1
# |   |   |--- volatile acidity >  0.41
# |   |   |   |--- total sulfur dioxide <= 157.00
# |   |   |   |   |--- density <= 0.99
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- density >  0.99
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- total sulfur dioxide >  157.00
# |   |   |   |   |--- class: 0

# %% [markdown]
# Алгоритмы классификации:
#
# Генеративные модели: изучают совместное распределение данных, вроде как элипсы [наивный байесовский классификатор, Байесовая сеть],
#     может использоваться для прогназирования в целом
#
#
# Дискриминационные модели: делят данные какими-то границами (правилами) [деревья решений, SVM, логистическая регрессия]
